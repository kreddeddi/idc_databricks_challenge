# %%
df =spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv", inferSchema=True, header=True)

# %%
df.show(10)

# %%
df_selected= df.select("product_id", "category_code", "brand", "price")
df_selected.show(50)

# %%
df_filtered = df.filter("price > 2500")
df_filtered.show()

# %%
df_grouped = df.groupBy("brand").count().orderBy("count", ascending=False)
df_grouped.show()

# %% [markdown]
# Top 5 brands

# %%
from pyspark.sql.functions import col
df_top = df_grouped.filter(col("brand").isNotNull()).limit(5)
df_top.show()
